# %% [markdown]
# ##Tropical Cyclones Workflow
#
# Detection -> Categorization -> Localization

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')

# %%
# %cd /content/drive/My Drive/ESRIN_PhiLab/Tropical_Cyclones/tropical_cyclones/src/code
# %ls

import imp 
# import helper.py
helper = imp.new_module('helper_functions')
exec(open("./helper_functions.py").read(), helper.__dict__)
# import models.py
models = imp.new_module('models')
exec(open("./models.py").read(), models.__dict__)
# import data_processor.py
dp = imp.new_module('data_processor')
exec(open("./data_processor.py").read(), dp.__dict__)

# %%
# insert your desired path to work on
# %cd /content/drive/My Drive/ESRIN_PhiLab/Tropical_Cyclones/data
# %ls

# %%
# general imports
import os
import sys
sys.stdout.flush()
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import math
from tensorflow import keras

np.set_printoptions(precision=4)

# %%
# load and prepare test set
test_set = ...

# load best models for each task
detector_model = keras.models.load_model('path/to/location')
classifier_model = keras.models.load_model('path/to/location')
locator_model = keras.models.load_model('path/to/location')

# detect the presence/absence of eye in frame
detector_prediction = detector_model.predict(test_set)
idx = np.where(detector_predictions == 1)[0]
test_set_with_eye = test_set[idx]

# if eye is present, categorize TC and locate its center
classifier_prediction = classifier_model.predict(test_set_with_eye)
locator_prediction = locator_model.predict(test_set_with_eye)
